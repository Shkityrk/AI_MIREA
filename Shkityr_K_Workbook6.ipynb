# %% [markdown]
# #1.1.1 Пример
# ##Задача:
# Пусть дана начальная популяция из четырех хромосом с двумя генами x и y. Показатель качества хромосомы оценивается функцией Z. При равном качестве хромосом предпочтение отдается хромосоме с большим номером. На каждом этапе хромосома a с высшим качеством порождает четыре новых хромосомы 𝑏1,𝑐1,𝑏2,𝑐2, обмениваясь генами с двумя хромосомами b и c более низкого качества по указанной схеме:
# Последняя хромоcома (с низшим качеством) выбывает из популяции. Найти максимальный показатель качества хромосомы в популяции и общее качество популяции после четырех этапов эволюции.
# Потребуется несколько функций для реализации алгоритма. Напишем их.

# %%
def qZ(x,y):
    return (x-3 * y+1)/(3*x**2+3*y**2+1)

def qSumZ(Z):
    return sum(Z)

def exchangeScheme(oldX, oldY, sortedId):
    X = [0 for i in range(4)]
    Y = [0 for i in range(4)]
    X[2] = oldX[sortedId[2]]
    X[3] = oldX[sortedId[2]]
    X[0] = oldX[sortedId[0]]
    X[1] = oldX[sortedId[1]]
    Y[0] = oldY[sortedId[2]]
    Y[1] = oldY[sortedId[2]]
    Y[2] = oldY[sortedId[0]]
    Y[3] = oldY[sortedId[1]]
    return X, Y

def sorting(Z):
    sortedId=sorted(range(len(Z)), key=lambda k:Z[k])
    return sortedId

def evoStep(X,Y,Z):
    _,minId = min((value, id) for (id, value) in enumerate(Z))
    X=X[:]
    Y=Y[:]
    Z=Z[:]
    X.pop(minId)
    Y.pop(minId)
    Z.pop(minId)
    
    return X,Y,Z

# %%
def evosteps(X, Y, stepsnum=4):
    results=[]

    for i in range(4):
        arrZ = [qZ(x, Y[i]) for i, x in enumerate(X)]
        X, Y, Z = evoStep(X, Y, arrZ)
        X, Y = exchangeScheme(X, Y, sorting(Z))

        results.append([X, Y, qSumZ(arrZ), arrZ])

    return X,Y,results

# %%
X = [-2,-1,0,1]
Y = [-2,-1,0,1]

results = evosteps(X,Y)

# %%
for i in range(len(results[2])):
    print(f'max_{i + 1}_step: {results[2][i][2]}')
qualityArrZ =[]
for i in range(len(results[2])): 
    qualityArrZ += results[2][i][3]
print(f'max Z:{max(qualityArrZ)}')
# Out:
# max_1_step: 1.4857142857142858
# max_2_step: 1.4615384615384615
# max_3_step: 2.967032967032967
# max_4_step: 3.5384615384615383
# max Z:1.0

# %% [markdown]
# # Задание:
# Выполните по вариантам соответственно реализацию генетического алгоритма в соответствии с приложенными начальными данными.

# %%
X = [-1, 0, 2, 3]
Y = [0, 1, -2, 2]

def qetZ(x,y):
    return (x-3*y)/(2*x**2 + 2*y**2 + 1)

def evoSteps_task(X, Y, stepsNum = 4): 
    results = []
    for i in range(4):
        arrZ = [qetZ(x, Y[i]) for i, x in enumerate(X)]
        X, Y, Z = evoStep(X, Y, arrZ)
        X, Y = exchangeScheme(X, Y, sorting(Z))
        results.append([X, Y, qSumZ(arrZ), arrZ])
    return X, Y, results

# %%
res = evoSteps_task(X,Y)

# %%
for i in range(len(res[2])):
    print(f'max_{i + 1}_step: {results[2][i][2]}')
qualityArrZ =[]
for i in range(len(res[2])): 
    qualityArrZ += res[2][i][3]
print(f'max Z:      {max(qualityArrZ)}')
# Out:
# max_1_step: 1.4857142857142858
# max_2_step: 1.4615384615384615
# max_3_step: 2.967032967032967
# max_4_step: 3.5384615384615383
# max Z:      0.47058823529411764

# %% [markdown]
# # 1.2.1 Пример

# %%
import networkx as nx
from math import e

distances =[(1,2,20),
            (1,3,40),
            (1,4,42),
            (1,5,33),
            (1,6,21),
            (2,3,26),
            (2,4,38),
            (2,5,42),
            (2,6,17),
            (3,4,22),
            (3,5,43), 
            (3,6,21), 
            (4,5,27),
            (4,6,22),
            (5,6,26)
            ]

V = [1, 4, 5, 2, 6, 3, 1] # последовательность прохождения маршрута
Z = [(3, 4),
     (4, 6),
     (5, 2), 
     (6, 2)] # последовательность замен вершин
P= [49, 54, 43, 54] # случайные числа, выпавшие в процессе счета
T= 100 # начальная температура

# %%
def probability(delta, T):
    return 100*e**(-delta / T)

# функция изменения температуры 
def reductTemp(prevT):
    nextT = 0.5 * prevT
    return nextT

graph = nx.Graph()
graph.add_weighted_edges_from(distances)

nx.draw_kamada_kawai(graph, 
                     node_color= '#fb7258', 
                     node_size=2000,
                     with_labels=True)

# %%
# вычисление длины ребра
def edgeLength(i, j, distances, roundTrip = True):
    if roundTrip: return max([(item[2] if (item[0] == i and item[1] == j) or (item[1] == i and item[0] == j) else -1) for item in distances])
    else:
        return max([(item[2] if (item[0] == i and item[1] == j) else -1) for item in distances])

def routeLength(V, distances): 
    edges = []
    for i in range(len(V) - 1):
        edges.append(edgeLength(V[i], V[i + 1], distances))
    return sum(edges)

def routeOneReplacement(arrV, Z, replacementByName = True):
    decrement = 1 if replacementByName else 0
    arrV[Z[0] - decrement], arrV[Z[1] - decrement] = arrV[Z[1] - decrement], arrV[Z[0] - decrement]
    return arrV

def routeReplacement(V,Z):
    for z in Z:
        V=routeOneReplacement(V,z)
    return V

# выбор нужного пути методом отжига
def chooseRoute(distances, V, Z, T, P):
    sumLength = routeLength(V, distances) # нахождение длины numa
    arrSum = [sumLength] # массив сумм длин
    # циклы методом отжига
    for i in range(len(Z)):
        newV = routeOneReplacement(V[:], Z[i]) # новый маршрут после перестановки
        newS = routeLength(newV, distances) # длина нового маршрута 
        arrSum.append(newS)
        deltas = newS - sumLength # разница между длиной нового и старого маршрутов
        # в случае, если разница между длиноми больше 0, то вычисляется вероятность 
        if deltas > 0:
            p = probability(deltas, T) # подсчёт вероятности
    # если заданная вероятность попадает в интервал от 0 до р, то новый маршрут выбирается
            if p > P[i]:
                V = newV
                sumLength = newS
        else:
            V = newV
            sumLength = newS
        T = reductTemp(T)
    return V, arrSum

def drawRouteGraph(distances, bestRoute):
    newDistances =[]
    # прохождение по вектору
    for i in range(len(bestRoute) - 1):
        for distance in distances:
            if distance[0] == bestRoute[i] and distance[1] == bestRoute[i + 1]or distance[1] == bestRoute[i] and distance[0] == bestRoute[i + 1]:
                    newDistances.append(distance)
   
    graph = nx.Graph() # создание пустого графа
    graph.add_weighted_edges_from(newDistances) # добавление весов рёбер
    # отрисовка графа с заданными вершинами
    nx.draw_kamada_kawai(graph, node_color = '#fb7258', node_size = 2000, with_labels = True)
    
    
bestRoute, arrLength = chooseRoute(distances, V, Z, T, P)
print(f'Лучший выбранный маршрут: {bestRoute}')
print(f'Длина лучшего выбранного маршрута: {routeLength(bestRoute, distances)}') 
print(f'Длины всеx pассмотренных маршрутов: {arrLength}')
drawRouteGraph(distances, bestRoute) # оmpuсовка лучшего маршрута
# Out:
# Лучший выбранный маршрут: [1, 6, 2, 3, 4, 5, 1]
# Длина лучшего выбранного маршрута: 146
# Длины всеx pассмотренных маршрутов: [189, 209, 186, 146, 166]

# %% [markdown]
# # Задание
# Найти длину гамильтонова цикла S4 в полном графе K6 после четырех циклов решения задачи методом отжига по вариантам ниже.

# %%
distances=[(1,2,19),
           (1,3,39), 
           (1,4,35), 
           (1,5,26),
           (1,6,18),
           (2,3,26),
           (2,3,26),
           (2,4,33),
           (2,5,37),
           (2,6,14), 
           (3,4,22), 
           (3,5,41), 
           (3,6,21),
           (4,5,22),
           (4,6,19), 
           (5,6,24)]

V=[1,4,2,3,5,6,1]
Z=[(5,2),
   (4,5),
   (2,3), 
   (3,4)]

P=[88,54,24,64]

# %%
graph = nx.Graph()
graph.add_weighted_edges_from(distances)

nx.draw_kamada_kawai(graph, 
                     node_color= '#fb7258', 
                     node_size=2000,
                     with_labels=True)

# %%
# выбор нужного пути методом отжига
def chooseRoute(distances, V, Z, T, P):
    sumLength = routeLength(V, distances) # нахождение длины numa
    arrSum = [sumLength] # массив сумм длин
    # циклы методом отжига
    for i in range(len(Z)):
        newV = routeOneReplacement(V[:], Z[i]) # новый маршрут после перестановки
        newS = routeLength(newV, distances) # длина нового маршрута 
        arrSum.append(newS)
        deltas = newS - sumLength # разница между длиной нового и старого маршрутов
        # в случае, если разница между длинами больше 0, то вычисляется вероятность 
        if deltas > 0:
            p = probability(deltas, T) # подсчёт вероятности
    # если заданная вероятность попадает в интервал от 0 до р, то новый маршрут выбирается
            if p > P[i]:
                V = newV
                sumLength = newS
        else:
            V = newV
            sumLength = newS
        T = reductTemp(T)
    return V, arrSum

# %%
bestRoute, arrLength = chooseRoute(distances, V, Z, T, P)
print(f'Лучший выбранный маршрут: {bestRoute}')
print(f'Длина лучшего выбранного маршрута: {routeLength(bestRoute, distances)}') 
print(f'Длины всеx pассмотренных маршрутов: {arrLength}')
drawRouteGraph(distances, bestRoute) # оmpuсовка лучшего маршрута
# Out:
# Лучший выбранный маршрут: [1, 2, 5, 4, 3, 6, 1]
# Длина лучшего выбранного маршрута: 139
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 139, 154]

# %% [markdown]
# # На решенном уже примере поэкспериментируйте с показателем S, проанализируйте результаты.

# %%
S_values = [i*10 for i in range(1,35,1)]  

for S in S_values:
    print(f"Тестируем значение S = {S}")
    bestRoute, arrLength = chooseRoute(distances, V, Z, T, [S]*len(Z))
    print(f'Лучший выбранный маршрут: {bestRoute}')
    print(f'Длина лучшего выбранного маршрута: {routeLength(bestRoute, distances)}') 
    print(f'Длины всеx pассмотренных маршрутов: {arrLength}\n')
# Out:
# Тестируем значение S = 10
# Лучший выбранный маршрут: [1, 2, 4, 5, 3, 6, 1]
# Длина лучшего выбранного маршрута: 154
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 139, 154]
#
# Тестируем значение S = 20
# Лучший выбранный маршрут: [1, 2, 4, 5, 3, 6, 1]
# Длина лучшего выбранного маршрута: 154
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 139, 154]
#
# Тестируем значение S = 30
# Лучший выбранный маршрут: [1, 2, 4, 5, 3, 6, 1]
# Длина лучшего выбранного маршрута: 154
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 139, 154]
#
# Тестируем значение S = 40
# Лучший выбранный маршрут: [1, 2, 5, 4, 3, 6, 1]
# Длина лучшего выбранного маршрута: 139
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 139, 154]
#
# Тестируем значение S = 50
# Лучший выбранный маршрут: [1, 2, 5, 4, 3, 6, 1]
# Длина лучшего выбранного маршрута: 139
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 139, 154]
#
# Тестируем значение S = 60
# Лучший выбранный маршрут: [1, 2, 5, 4, 3, 6, 1]
# Длина лучшего выбранного маршрута: 139
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 139, 154]
#
# Тестируем значение S = 70
# Лучший выбранный маршрут: [1, 2, 5, 4, 3, 6, 1]
# Длина лучшего выбранного маршрута: 139
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 139, 154]
#
# Тестируем значение S = 80
# Лучший выбранный маршрут: [1, 2, 5, 4, 3, 6, 1]
# Длина лучшего выбранного маршрута: 139
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 139, 154]
#
# Тестируем значение S = 90
# Лучший выбранный маршрут: [1, 5, 2, 3, 4, 6, 1]
# Длина лучшего выбранного маршрута: 148
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 156, 163]
#
# Тестируем значение S = 100
# Лучший выбранный маршрут: [1, 5, 2, 3, 4, 6, 1]
# Длина лучшего выбранного маршрута: 148
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 156, 163]
#
# Тестируем значение S = 110
# Лучший выбранный маршрут: [1, 5, 2, 3, 4, 6, 1]
# Длина лучшего выбранного маршрута: 148
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 156, 163]
#
# Тестируем значение S = 120
# Лучший выбранный маршрут: [1, 5, 2, 3, 4, 6, 1]
# Длина лучшего выбранного маршрута: 148
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 156, 163]
#
# Тестируем значение S = 130
# Лучший выбранный маршрут: [1, 5, 2, 3, 4, 6, 1]
# Длина лучшего выбранного маршрута: 148
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 156, 163]
#
# Тестируем значение S = 140
# Лучший выбранный маршрут: [1, 5, 2, 3, 4, 6, 1]
# Длина лучшего выбранного маршрута: 148
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 156, 163]
#
# Тестируем значение S = 150
# Лучший выбранный маршрут: [1, 5, 2, 3, 4, 6, 1]
# Длина лучшего выбранного маршрута: 148
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 156, 163]
#
# Тестируем значение S = 160
# Лучший выбранный маршрут: [1, 5, 2, 3, 4, 6, 1]
# Длина лучшего выбранного маршрута: 148
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 156, 163]
#
# Тестируем значение S = 170
# Лучший выбранный маршрут: [1, 5, 2, 3, 4, 6, 1]
# Длина лучшего выбранного маршрута: 148
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 156, 163]
#
# Тестируем значение S = 180
# Лучший выбранный маршрут: [1, 5, 2, 3, 4, 6, 1]
# Длина лучшего выбранного маршрута: 148
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 156, 163]
#
# Тестируем значение S = 190
# Лучший выбранный маршрут: [1, 5, 2, 3, 4, 6, 1]
# Длина лучшего выбранного маршрута: 148
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 156, 163]
#
# Тестируем значение S = 200
# Лучший выбранный маршрут: [1, 5, 2, 3, 4, 6, 1]
# Длина лучшего выбранного маршрута: 148
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 156, 163]
#
# Тестируем значение S = 210
# Лучший выбранный маршрут: [1, 5, 2, 3, 4, 6, 1]
# Длина лучшего выбранного маршрута: 148
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 156, 163]
#
# Тестируем значение S = 220
# Лучший выбранный маршрут: [1, 5, 2, 3, 4, 6, 1]
# Длина лучшего выбранного маршрута: 148
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 156, 163]
#
# Тестируем значение S = 230
# Лучший выбранный маршрут: [1, 5, 2, 3, 4, 6, 1]
# Длина лучшего выбранного маршрута: 148
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 156, 163]
#
# Тестируем значение S = 240
# Лучший выбранный маршрут: [1, 5, 2, 3, 4, 6, 1]
# Длина лучшего выбранного маршрута: 148
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 156, 163]
#
# Тестируем значение S = 250
# Лучший выбранный маршрут: [1, 5, 2, 3, 4, 6, 1]
# Длина лучшего выбранного маршрута: 148
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 156, 163]
#
# Тестируем значение S = 260
# Лучший выбранный маршрут: [1, 5, 2, 3, 4, 6, 1]
# Длина лучшего выбранного маршрута: 148
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 156, 163]
#
# Тестируем значение S = 270
# Лучший выбранный маршрут: [1, 5, 2, 3, 4, 6, 1]
# Длина лучшего выбранного маршрута: 148
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 156, 163]
#
# Тестируем значение S = 280
# Лучший выбранный маршрут: [1, 5, 2, 3, 4, 6, 1]
# Длина лучшего выбранного маршрута: 148
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 156, 163]
#
# Тестируем значение S = 290
# Лучший выбранный маршрут: [1, 5, 2, 3, 4, 6, 1]
# Длина лучшего выбранного маршрута: 148
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 156, 163]
#
# Тестируем значение S = 300
# Лучший выбранный маршрут: [1, 5, 2, 3, 4, 6, 1]
# Длина лучшего выбранного маршрута: 148
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 156, 163]
#
# Тестируем значение S = 310
# Лучший выбранный маршрут: [1, 5, 2, 3, 4, 6, 1]
# Длина лучшего выбранного маршрута: 148
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 156, 163]
#
# Тестируем значение S = 320
# Лучший выбранный маршрут: [1, 5, 2, 3, 4, 6, 1]
# Длина лучшего выбранного маршрута: 148
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 156, 163]
#
# Тестируем значение S = 330
# Лучший выбранный маршрут: [1, 5, 2, 3, 4, 6, 1]
# Длина лучшего выбранного маршрута: 148
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 156, 163]
#
# Тестируем значение S = 340
# Лучший выбранный маршрут: [1, 5, 2, 3, 4, 6, 1]
# Длина лучшего выбранного маршрута: 148
# Длины всеx pассмотренных маршрутов: [177, 148, 157, 156, 163]
